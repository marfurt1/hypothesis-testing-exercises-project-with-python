# %% [markdown]
# # Hypothesis testing problem

# %% [markdown]
# ### **Exercise 1**
#
# #### ANOVA
#
# Suppose that a study wants to check if there is a significant difference between the goal averages of soccer players depending on the position in which they play. In case there is a difference, you want to know which positions differ from the rest.
#
# NOTE: You must replace the values <<<FIXME>>>.
#
# **Exercise: Load data from "datos_laliga.csv". It contains a sample of randomly selected players.**

# %%
import pandas as pd
Datos= pd.read_csv("./assets/datos_laliga.csv")

Datos
# Out:
#     id_player position  average
# 0      id_189       DC    0.310
# 1       id_85       DC    0.306
# 2      id_105       DC    0.320
# 3       id_34       DC    0.329
# 4       id_32       DC    0.369
# ..        ...      ...      ...
# 322    id_231       DC    0.381
# 323     id_20       MP    0.310
# 324    id_294       DC    0.340
# 325    id_218       DC    0.305
# 326    id_110       DC    0.288
#
# [327 rows x 3 columns]

# %%
Datos.describe()
# Out:
#           average
# count  327.000000
# mean     0.332159
# std      0.035702
# min      0.174000
# 25%      0.309000
# 50%      0.331000
# 75%      0.354500
# max      0.437000

# %%
Datos.hist(column="average")
# Out:
# array([[<AxesSubplot:title={'center':'average'}>]], dtype=object)

# %%
Datos.hist(column= "average",by="position")
# Out:
# array([[<AxesSubplot:title={'center':'DC'}>,
#         <AxesSubplot:title={'center':'MO'}>],
#        [<AxesSubplot:title={'center':'MP'}>,
#         <AxesSubplot:title={'center':'P'}>]], dtype=object)

# %%
Datos.position.value_counts()
# Out:
# DC    154
# MP    120
# P      39
# MO     14
# Name: position, dtype: int64

# %%
Datos.boxplot(column="average",by="position")
# Out:
# <AxesSubplot:title={'center':'average'}, xlabel='position'>

# %% [markdown]
# **Exercise: Identify the number of groups and number of observations per group to determine if it is a balanced model. The mean and standard deviation of the group are also calculated.**

# %%
pd.crosstab(Datos["position"],columns=["average"])
#["DC", "MO", "MP", "P"])
#DC: Delantero centro
#MO: Medio ofensivo
#MP: Media punta
#P: Puntero
# Out:
# col_0     average
# position
# DC            154
# MO             14
# MP            120
# P              39

# %% [markdown]
# **Exercise: Calculate the mean and standar deviation by position**

# %%
Datos.groupby('position')['average'].agg('mean')
# Out:
# position
# DC    0.331526
# MO    0.347786
# MP    0.334250
# P     0.322615
# Name: average, dtype: float64

# %% [markdown]
# **Exercise: Calculate the standard deviation by position**

# %%
Datos.groupby('position')['average'].agg('sdt')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb Cell 10' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000009vscode-remote?line=0'>1</a> Datos.groupby('position')['average'].agg('sdt')
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/generic.py:265, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/generic.py?line=261'>262</a>     kwargs = {}
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/generic.py?line=263'>264</a> if isinstance(func, str):
# --> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/generic.py?line=264'>265</a>     return getattr(self, func)(*args, **kwargs)
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/generic.py?line=266'>267</a> elif isinstance(func, abc.Iterable):
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/generic.py?line=267'>268</a>     # Catch instances of lists / tuples
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/generic.py?line=268'>269</a>     # but not the class list / tuple itself.
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/generic.py?line=269'>270</a>     func = maybe_mangle_lambdas(func)
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/groupby.py?line=900'>901</a> if attr in self.obj:
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/groupby.py?line=901'>902</a>     return self[attr]
# --> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/groupby.py?line=903'>904</a> raise AttributeError(
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/groupby.py?line=904'>905</a>     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/groupby/groupby.py?line=905'>906</a> )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'sdt'

# %% [markdown]
# Since the number of observations per group is not constant, it is an unbalanced model. It is important to take this into account when checking the conditions of normality and homoscedasticity (s1 = s2 = s3 = s4). The most useful graphical representation before performing an ANOVA is the Box-Plot model.
#
# **Exercise: Plot a boxplot for each position**

# %%
# Boxplots
# This is another way and popular package used in R (ggplot)
from plotnine import *

(
    ggplot(Datos)  # What data to use
    + aes(x="position", y="average")  # What variable to use
    + geom_boxplot()  # Geometric object to use for drawing
    + theme_bw()
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb Cell 12' in <cell line: 3>()
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000011vscode-remote?line=0'>1</a> # Boxplots
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000011vscode-remote?line=1'>2</a> # This is another way and popular package used in R (ggplot)
# ----> <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000011vscode-remote?line=2'>3</a> from plotnine import *
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000011vscode-remote?line=4'>5</a> (
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000011vscode-remote?line=5'>6</a>     ggplot(Datos)  # What data to use
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000011vscode-remote?line=6'>7</a>     + aes(x="position", y="average")  # What variable to use
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000011vscode-remote?line=7'>8</a>     + geom_boxplot()  # Geometric object to use for drawing
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000011vscode-remote?line=8'>9</a>     + theme_bw()
#      <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000011vscode-remote?line=9'>10</a> )
#
# ModuleNotFoundError: No module named 'plotnine'

# %% [markdown]
# #### Independence
#
# The total sample size is <10% of the population of all players in the league. The groups (categorical variable) are independent of each other since a random sample of players from the entire league (not just from the same team) has been made.
#
# Normal distribution of observations: The quantitative variable must be distributed in a normal way in each of the groups. The normality study can be done graphically (qqplot) or with a hypothesis test.
#
# **Exercise: Make an analysis about normal distribution for each position**

# %%
import numpy as np 
import pylab 
import matplotlib.pyplot as plt
import scipy.stats as stats

measurements = Datos.loc[Datos["position"] == "P","average"]
stats.probplot(measurements, dist="norm", plot=pylab)
plt.title("P")
plt.show()

measurements = Datos.loc[Datos["position"] == "MO","average"]
stats.probplot(measurements, dist="norm", plot=pylab)
plt.title("MO")
plt.show()

measurements = Datos.loc[Datos["position"] == "DC","average"]
stats.probplot(measurements, dist="norm", plot=pylab)
plt.title("DC")
plt.show()

measurements = Datos[Datos["position"] == "MP","average"]
stats.probplot(measurements, dist="norm", plot=pylab)
plt.title("MP")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 322    False
# 323     True
# 324    False
# 325    False
# 326    False
# Name: position, Length: 327, dtype: bool, 'average')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb Cell 14' in <cell line: 21>()
#      <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000013vscode-remote?line=17'>18</a> plt.title("DC")
#      <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000013vscode-remote?line=18'>19</a> plt.show()
# ---> <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000013vscode-remote?line=20'>21</a> measurements = Datos[Datos["position"] == "MP","average"]
#      <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000013vscode-remote?line=21'>22</a> stats.probplot(measurements, dist="norm", plot=pylab)
#      <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000013vscode-remote?line=22'>23</a> plt.title("MP")
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py:3628, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>         raise KeyError(key) from err
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a>     except TypeError:
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>         # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>         #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>         #  the TypeError.
# -> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>         self._check_indexing_error(key)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3628'>3629</a>         raise
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3630'>3631</a> # GH#42269
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py:5637, in Index._check_indexing_error(self, key)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5632'>5633</a> def _check_indexing_error(self, key):
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5633'>5634</a>     if not is_scalar(key):
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5634'>5635</a>         # if key is not a scalar, directly raise an error (the code below
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5635'>5636</a>         # would convert to numpy arrays and raise later any way) - GH29926
# -> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5636'>5637</a>         raise InvalidIndexError(key)
#
# InvalidIndexError: (0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 322    False
# 323     True
# 324    False
# 325    False
# 326    False
# Name: position, Length: 327, dtype: bool, 'average')

# %% [markdown]
# **Exercise: make the boxplot for each position, what you can say about them?**

# %%
# Using plotly
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Box(y=Datos.loc[Datos["position"] == "P","average"]))
fig.add_trace(go.Box(y=Datos.loc[Datos["position"] == "MO","average"]))
fig.add_trace(go.Box(y=Datos.loc[Datos["position"] == "DC","average"]))
fig.add_trace(go.Box(y=Datos.loc[Datos["position"] == "MP","average"]))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb Cell 16' in <cell line: 2>()
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000015vscode-remote?line=0'>1</a> # Using plotly
# ----> <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000015vscode-remote?line=1'>2</a> import plotly.graph_objects as go
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000015vscode-remote?line=3'>4</a> fig = go.Figure()
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000015vscode-remote?line=4'>5</a> fig.add_trace(go.Box(y=Datos.loc[Datos["position"] == "P","average"]))
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# **Exercise: Use the Kolmogorov-Smirnov test or with or without the Lilliefors correction in order to know the normality distribution.**

# %%
# Beginner way to do it

from statsmodels.stats.diagnostic import lilliefors

my_df = pd.Datos(index=np.arange(len(np.unique(Datos["position"]))), columns=["position", "D_statistic", "p_value"])
my_df["position"] = np.unique(Datos["position"])

for position in my_df["position"]:
    Datos_subset = Datos.loc[Datos["position"] == position,:]
    D_statistic, p_value = lilliefors(Datos_subset.average)
    my_df.loc[my_df["position"]==position,["D_statistic", "p_value"]] = D_statistic, p_value
    
print(my_df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb Cell 18' in <cell line: 3>()
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000017vscode-remote?line=0'>1</a> # Beginner way to do it
# ----> <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000017vscode-remote?line=2'>3</a> from statsmodels.stats.diagnostic import lilliefors
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000017vscode-remote?line=4'>5</a> my_df = pd.Datos(index=np.arange(len(np.unique(Datos["position"]))), columns=["position", "D_statistic", "p_value"])
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000017vscode-remote?line=5'>6</a> my_df["position"] = np.unique(Datos["position"])
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
#Another way to do it (Highly recommendable)
Data_Frame.groupby("position")["average"].apply(lilliefors)

# %% [markdown]
# The hypothesis tests do not show evidence of a lack of normality.
#
# Constant variance between groups (homoscedasticity):
#
# Given that there is a group (DC) that is at the limit to accept that it is distributed in a normal way, the Fisher and Bartlett tests are not recommended. Instead it is better to use a test based on the median Levene test or the Fligner-Killeen test.
#
# **Exercise: use the fligner and levene functions from scipy.stats in order to know the homocedasticy**

# %%
from scipy import stats

values_array = pd.Datos(Datos.groupby("position")["average"]).to_numpy()

print(stats.fligner(values_array[0,1], values_array[1,1], values_array[2,1], values_array[3,1]))

print(stats.levene(values_array[0,1], values_array[1,1], values_array[2,1], values_array[3,1]))

# stats.fligner(values_array[:,1]) # It doesn't work, please analyse
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb Cell 21' in <cell line: 3>()
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000020vscode-remote?line=0'>1</a> from scipy import stats
# ----> <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000020vscode-remote?line=2'>3</a> values_array = pd.Datos(Datos.groupby("position")["average"]).to_numpy()
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000020vscode-remote?line=4'>5</a> print(stats.fligner(values_array[0,1], values_array[1,1], values_array[2,1], values_array[3,1]))
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-ygeq65ktdue.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000020vscode-remote?line=6'>7</a> print(stats.levene(values_array[0,1], values_array[1,1], values_array[2,1], values_array[3,1]))
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/__init__.py:261, in __getattr__(name)
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/__init__.py?line=256'>257</a>     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/__init__.py?line=258'>259</a>     return _SparseArray
# --> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/__init__.py?line=260'>261</a> raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Datos'

# %% [markdown]
# There is no significant evidence of lack of homoscedasticity in either of the two tests.
#
# The study of the conditions can be carried out after calculating the ANOVA, since if they are not fulfilled, it does not make much sense to continue. However, the most appropriate way to verify that the necessary conditions are satisfied is by studying the model residuals once the ANOVA has been generated.
#
# **Exercise: make an ANOVA table and analyze the p-value using the packages statsmodels and the bioinfokit**

# %%
# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('average ~ position', data= Datos).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table

# %%
# ANOVA with package bioinfokit
from bioinfokit.analys import stat
res = stat()
res.anova_stat(df=Datos, res_var='value', anova_model='average ~ position')
res.anova_summary
# output (ANOVA F and p value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb Cell 24' in <cell line: 2>()
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-7ef7fp4bxsf.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000023vscode-remote?line=0'>1</a> # ANOVA with package bioinfokit
# ----> <a href='vscode-notebook-cell://marfurt1-hypothesistest-7ef7fp4bxsf.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000023vscode-remote?line=1'>2</a> from bioinfokit.analys import stat
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-7ef7fp4bxsf.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000023vscode-remote?line=2'>3</a> res = stat()
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-7ef7fp4bxsf.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000023vscode-remote?line=3'>4</a> res.anova_stat(df=Data_Frame, res_var='value', anova_model='average ~ position')
#
# ModuleNotFoundError: No module named 'bioinfokit'

# %% [markdown]
# **Exercise: make a plot of the fitted values vs residuals. Make the plot of the Standardized Residuals. Make the histogram of the residuals.**

# %%
# QQ-plot
import statsmodels.api as sm
import matplotlib.pyplot as plt


plt.scatter(res.anova_model_out.fittedvalues, res.anova_model_out.resid)
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Residuals vs. Fitted")
plt.show()

# res.anova_std_residuals are standardized residuals obtained from ANOVA (check above)
sm.qqplot(res.anova_std_residuals, line='45')
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Standardized Residuals")
plt.show()

# histogram
plt.hist(res.anova_model_out.resid, bins='auto', histtype='bar', ec='k') 
plt.xlabel("Residuals")
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb Cell 26' in <cell line: 2>()
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-7ef7fp4bxsf.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000025vscode-remote?line=0'>1</a> # QQ-plot
# ----> <a href='vscode-notebook-cell://marfurt1-hypothesistest-7ef7fp4bxsf.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000025vscode-remote?line=1'>2</a> import statsmodels.api as sm
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-7ef7fp4bxsf.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000025vscode-remote?line=2'>3</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell://marfurt1-hypothesistest-7ef7fp4bxsf.ws-us46.gitpod.io/workspace/hypothesis-testing-exercises-project-with-python/notebook/problems.ipynb#ch0000025vscode-remote?line=5'>6</a> plt.scatter(res.anova_model_out.fittedvalues, res.anova_model_out.resid)
#
# ModuleNotFoundError: No module named 'statsmodels'

# %% [markdown]
# Given that the p-value is higher than 0.05, there is not enough evidence to consider that at least two means are different. The graphical representation of the residuals does not show lack of homoscedasticity (graph 1) and in the qqplot the residuals are distributed very close to the normal line (graph 2 and 3).

# %% [markdown]
# ### **Exercise 2**
#
# #### T-TEST INDEPENDENT
#
# A professor gives online lectures. Later, he uploads recorded lectures to the cloud for students who followed the course asynchronously (those who did not attend the lesson but later watched the records). However, he believes that the students who attend class at the class time and participate in the process are more successful. Therefore, he recorded the average grades of the students at the end of the semester. The data is below.
#
# ```py
# synchronous = [94. , 84.9, 82.6, 69.5, 80.1, 79.6, 81.4, 77.8, 81.7, 78.8, 73.2, 87.9, 87.9, 93.5, 82.3, 79.3, 78.3, 71.6, 88.6, 74.6, 74.1, 80.6]
#
#
# asynchronous = [77.1, 71.7, 91. , 72.2, 74.8, 85.1, 67.6, 69.9, 75.3, 71.7, 65.7, 72.6, 71.5, 78.2]
# ```
#
# Conduct the hypothesis testing to check whether the professor’s belief is statistically significant by using a 0.05 significance level to evaluate the null and alternative hypotheses. Before doing hypothesis testing, check the related assumptions. Comment on the results.

# %% [markdown]
# **1. Defining Hypothesis**
#
# H₀: μₛ≤μₐ
#
# H₁: μₛ>μₐ

# %% [markdown]
# **2. Assumption Check**
#
# H₀: The data is normally distributed.
#
# H₁: The data is not normally distributed.
#
# Assume that α=0.05. If the p-value is >0.05, it can be said that data is normally distributed.

# %%
# import libraries
import numpy as np
from scipy import stats
import pandas as pd

# %%
def check_normality(data):
    test_stat_normality, p_value_normality=stats.shapiro(data)
    print("p value:%.4f" % p_value_normality)
    if p_value_normality <0.05:
        print("Reject null hypothesis >> The data is not normally distributed")
    else:
        print("Fail to reject null hypothesis >> The data is normally distributed")

# %%
#define veriables
def check_variance_homogeneity(group1, group2):
    test_stat_var, p_value_var= stats.levene(group1,group2)
    print("p value:%.4f" % p_value_var)
    if p_value_var <0.05:
        print("Reject null hypothesis >> The variances of the samples are different.")
    else:
        print("Fail to reject null hypothesis >> The variances of the samples are same.")

# %%
sync = np.array([94. , 84.9, 82.6, 69.5, 80.1, 79.6, 81.4, 77.8, 81.7, 78.8, 73.2,
       87.9, 87.9, 93.5, 82.3, 79.3, 78.3, 71.6, 88.6, 74.6, 74.1, 80.6])
asyncr = np.array([77.1, 71.7, 91. , 72.2, 74.8, 85.1, 67.6, 69.9, 75.3, 71.7, 65.7, 72.6, 71.5, 78.2])

# %%
#check normality
check_normality(sync)
check_normality(asyncr)
# Out:
# p value:0.6556
# Fail to reject null hypothesis >> The data is normally distributed
# p value:0.0803
# Fail to reject null hypothesis >> The data is normally distributed

# %% [markdown]
# H₀: The variances of the samples are the same.
#
# H₁: The variances of the samples are different.

# %%
def check_variance_homogeneity(group1, group2):
    test_stat_var, p_value_var= stats.levene(group1,group2)
    print("p value:%.4f" % p_value_var)
    if p_value_var <0.05:
        print("Reject null hypothesis >> The variances of the samples are different.")
    else:
        print("Fail to reject null hypothesis >> The variances of the samples are same.")

# %% [markdown]
# It tests the null hypothesis that the population variances are equal (called homogeneity of variance or homoscedasticity). Suppose the resulting p-value of Levene’s test is less than the significance level (typically 0.05). In that case, the obtained differences in sample variances are unlikely to have occurred based on random sampling from a population with equal variances.

# %%
#check_variance_homogeneity
check_variance_homogeneity(sync, asyncr)
# Out:
# p value:0.8149
# Fail to reject null hypothesis >> The variances of the samples are same.

# %% [markdown]
# Are assumptions satisfied?

# %%
#perform the parametric version of the test for 2 groups and unpaired data.
ttest,p_value = stats.ttest_ind(sync,asyncr)
print("p value:%.8f" % p_value)
print("since the hypothesis is one sided >> use p_value/2 >> p_value_one_sided:%.4f" %(p_value/2))
if p_value/2 <0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# p value:0.00753598
# since the hypothesis is one sided >> use p_value/2 >> p_value_one_sided:0.0038
# Reject null hypothesis

# %% [markdown]
# Macke a conclusion
